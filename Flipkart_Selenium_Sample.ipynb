# %%
# !google-chrome --version
# Out:
# Google Chrome 103.0.5060.134

# %%
# !chromedriver -v
# Out:
# ChromeDriver 103.0.5060.53 (a1711811edd74ff1cf2150f36ffa3b0dae40b17f-refs/branch-heads/5060@{#853})

# %%
import pandas as pd
import numpy as np
from selenium import webdriver
import time

# %%
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--headless')
chrome_options.add_argument('--disable-gpu')
chrome_options.add_argument('--disable-dev-shm-usage')
chrome_options.add_argument('--incognito')
chrome_options.add_argument('--start-maximized')
chrome_options.add_argument("--window-size=1920,1080")
chrome_options.add_argument('-disk-cache-size-300000000000')
driver = webdriver.Chrome(options=chrome_options)

driver.get(r'https://www.flipkart.com/apple-iphone-7-black-32-gb/product-reviews/itmen6daftcqwzeg?pid=MOBEMK62PN2HU7EE&lid=LSTMOBEMK62PN2HU7EEINTGNU&marketplace=FLIPKART')
time.sleep(5)

print("It Works")

Name = []
Rating = []
Heading = []
Result = []

Count =0
while driver.find_element_by_class_name("_1LKTO3"):
    Count+=1
    if(Count >= 5):
        break

    Review_Elements = driver.find_elements_by_xpath("//div[@class='_1AtVbE col-12-12']/div/div/div[@class='col _2wzgFH K0kLPL']")
    for review in Review_Elements:
        for review1 in review.find_elements_by_xpath("//div[@class='row _3n8db9']/div/p[@class='_2sc7ZR _2V5EHH']"):
            name = review1.text
            Name.append(name)
        for review2 in review.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']"):
            rating = review2.text
            if(rating==""):
                print("Null Value at " + Count)
            Rating.append(rating)
        for review3 in review.find_elements_by_xpath("//div[@class='col _2wzgFH K0kLPL']/div/p[@class='_2-N8zT']"):
            heading = review3.text
            Heading.append(heading)
        for review4 in review.find_elements_by_xpath("//div[@class='t-ZTKy']"):
            result = review4.text
            Result.append(result)
        break
    driver.find_elements_by_class_name("_1LKTO3")[-1].click()
    time.sleep(4)
# Out:
# It Works

# %%
AllInfo = pd.DataFrame(np.column_stack([Name, Rating, Heading, Result]), columns=["Name","Rating","Heading","Result"])

# %%
AllInfo
# Out:
#                    Name Rating  \
# 0            Hemanta Sa      5
# 1     Ezzazuddin Huseni      5
# 2           Anish Singh      5
# 3              suresh b      4
# 4      Gautam Choudhary      5
# 5     Flipkart Customer      4
# 6         Mayank Chaube      5
# 7    Shariq Ahmad Beigh      5
# 8   chandan kumar panda      5
# 9         Preeti Kureel      4
# 10           Hemanta Sa      5
# 11    Ezzazuddin Huseni      5
# 12          Anish Singh      5
# 13             suresh b      4
# 14     Gautam Choudhary      5
# 15    Flipkart Customer      4
# 16        Mayank Chaube      5
# 17   Shariq Ahmad Beigh      5
# 18  chandan kumar panda      5
# 19        Preeti Kureel      4
# 20            Satej Rao      5
# 21   SUDHIR KUMAR BARAL      5
# 22        Amit Sankrani      5
# 23          Aftab Mulla      5
# 24        Nitish Dhawan      5
# 25     Saurabh Majumdar      5
# 26         Nikunj Gupta      5
# 27         sougata bose      5
# 28     Gunit Singh Keer      5
# 29          Sumit Kumar      5
# 30            Satej Rao      5
# 31   SUDHIR KUMAR BARAL      5
# 32        Amit Sankrani      5
# 33          Aftab Mulla      5
# 34        Nitish Dhawan      5
# 35     Saurabh Majumdar      5
# 36         Nikunj Gupta      5
# 37         sougata bose      5
# 38     Gunit Singh Keer      5
# 39          Sumit Kumar      5
#
#                                               Heading  \
# 0                                   Worth every penny
# 1                                           Must buy!
# 2                                      Simply awesome
# 3                                         Pretty good
# 4                                   Worth every penny
# 5                                         Pretty good
# 6                                    Perfect product!
# 7                                             Awesome
# 8                                       Great product
# 9                                         Pretty good
# 10                                  Worth every penny
# 11                                          Must buy!
# 12                                     Simply awesome
# 13                                        Pretty good
# 14                                  Worth every penny
# 15                                        Pretty good
# 16                                   Perfect product!
# 17                                            Awesome
# 18                                      Great product
# 19                                        Pretty good
# 20                A Worthy Upgrade from IPhone 6 Plus
# 21      Feedback on purchases of iPhone7 and Flipkart
# 22           Awesome piece of art to be used in Earth
# 23  Apple countinues to outperform with its new ma...
# 24                                      Awesome phone
# 25                                i (for ideal) phone
# 26                                     Gorgeous black
# 27                         iPhone 7 .... just awesome
# 28                                             Super!
# 29                 The pretty powerhouse in your hand
# 30                A Worthy Upgrade from IPhone 6 Plus
# 31      Feedback on purchases of iPhone7 and Flipkart
# 32           Awesome piece of art to be used in Earth
# 33  Apple countinues to outperform with its new ma...
# 34                                      Awesome phone
# 35                                i (for ideal) phone
# 36                                     Gorgeous black
# 37                         iPhone 7 .... just awesome
# 38                                             Super!
# 39                 The pretty powerhouse in your hand
#
#                                                Result
# 0   Thank u Flipkart for your fast delivery. It is...
# 1   From last 5 years my younger brother was using...
# 2   My first iPhone ❤️\nGot 3 days before expected...
# 3   excellent phone camera is very nice and the st...
# 4   Awesome Smartphone for iPhone lover..\nI got i...
# 5   I have been using the earlier versions of iPho...
# 6   IMPORTANT NOTICE\nIf you buy some apple device...
# 7   Well, what can I say... iPhone is awesome as e...
# 8   amazing phone\nmy first i phone 7\nit is reall...
# 9   good I phone 7 rose gold and best camera,best ...
# 10  Thank u Flipkart for your fast delivery. It is...
# 11  From last 5 years my younger brother was using...
# 12  My first iPhone ❤️\nGot 3 days before expected...
# 13  excellent phone camera is very nice and the st...
# 14  Awesome Smartphone for iPhone lover..\nI got i...
# 15  I have been using the earlier versions of iPho...
# 16  IMPORTANT NOTICE\nIf you buy some apple device...
# 17  Well, what can I say... iPhone is awesome as e...
# 18  amazing phone\nmy first i phone 7\nit is reall...
# 19  good I phone 7 rose gold and best camera,best ...
# 20  Shift to IPhone 7 from IPhone 6 Plus\n3 featur...
# 21  iPhone7 is awesome. I'm using the phone since ...
# 22  This is a master piece of the inventions from ...
# 23  I'm using iPhone from 3GS generation. I have u...
# 24  GOOD:\n+ water resistant - this is a huge impr...
# 25  It would be presumptuous to not acknowledge th...
# 26  iPhone 7 was launched at 7 PM IST on October 7...
# 27  Awesome phone in all means.\n1. Lookwise elega...
# 28  Its a very good phone. Some people might say i...
# 29  Delighted to have my hands on the very first d...
# 30  Shift to IPhone 7 from IPhone 6 Plus\n3 featur...
# 31  iPhone7 is awesome. I'm using the phone since ...
# 32  This is a master piece of the inventions from ...
# 33  I'm using iPhone from 3GS generation. I have u...
# 34  GOOD:\n+ water resistant - this is a huge impr...
# 35  It would be presumptuous to not acknowledge th...
# 36  iPhone 7 was launched at 7 PM IST on October 7...
# 37  Awesome phone in all means.\n1. Lookwise elega...
# 38  Its a very good phone. Some people might say i...
# 39  Delighted to have my hands on the very first d...
